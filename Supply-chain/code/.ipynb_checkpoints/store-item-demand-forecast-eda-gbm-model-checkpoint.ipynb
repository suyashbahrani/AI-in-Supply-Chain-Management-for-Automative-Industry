# %% [markdown]
# ## Store item demand forcast

# %% [markdown]
# ### 1.0 Import library

# %%
# Import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import gc
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import lightgbm as lgb
plt.style.use('ggplot')
# %matplotlib inline
seed = 433
# Out:
# /opt/conda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ### 1.2 Load dataset

# %%
#path ='dataset/'
path ='../input/'
train = pd.read_csv(path + 'train.csv',parse_dates=[0],nrows=None)
test = pd.read_csv(path+ 'test.csv',parse_dates=[1], nrows=None )
print('Number of rows and columns in train dataset are:',train.shape)
print('Number of rows and columns in test dataset are:', test.shape)
# Out:
# Number of rows and columns in train dataset are: (913000, 4)
# Number of rows and columns in test dataset are: (45000, 4)

# %% [markdown]
# ### 1.3 Useful function

# %%
def basic_details(df):
    """Find number of missing value,dtyeps, unique value in 
    dataset"""
    k = pd.DataFrame()
    k['Missing value'] = df.isnull().sum()
    k['% Missing value'] = df.isnull().sum()/df.shape[0]
    k['dtype'] = df.dtypes
    k['N unique'] = df.nunique()
    return k

# %%
def agg_stats(df,statistics,groupby_column):
    """Aggregate a column by unit sales statistics such as 
    'mean','sum','min','max', 'var', 'std',"""
    f,ax = plt.subplots(3,2,figsize=(14,8))
    ax =ax.ravel()
    for i,s in enumerate(statistics):
        tmp = (df
         .groupby(groupby_column)
         .agg({'sales':s})
         )
        tmp.columns = ['sales_{}'.format(s)]
        sns.lineplot(x=tmp.index, y = tmp.iloc[:,0],color='blue',ax=ax[i])
        ax[i].set_xticks(tmp.index)
        for ticks in ax[i].get_xticklabels(): ticks.set_rotation(90)
        #plt.xticks(rotation=90)
        ax[i].set_title('sales_{}'.format(s))
        ax[i].set_ylabel('')
    plt.tight_layout()

# %%
### date_time_feat
def date_time_feat(df,column):
    "Extract date time feature"
    df['day'] = df[column].dt.day
    df['dayofweek'] = df[column].dt.dayofweek
    df['month'] = df[column].dt.month
    df['year'] = df[column].dt.year
    
    df['is_month_end'] = df[column].dt.is_month_end.astype('int8')
    df['is_month_start'] = df[column].dt.is_month_start.astype('int8')
    df['weekofyear'] = df[column].dt.weekofyear
    # conver to category
    #df['dayofweek'] = pd.Categorical(df['dayofweek'],
     #       categories=['Monday','Tuesday', 'Wednesday', 'Thursday', 'Friday','Saturday', 'Sunday',])

# %%
# Reduce memory of dataset
def reduce_memory_usage(df):
    """ The function will reduce memory of dataframe """
    intial_memory = df.memory_usage().sum()/1024**2
    print('Intial memory usage:',intial_memory,'MB')
    for col in df.columns:
        mn = df[col].min()
        mx = df[col].max()
        if df[col].dtype != object:            
            if df[col].dtype == int:
                if mn >=0:
                    if mx < np.iinfo(np.uint8).max:
                        df[col] = df[col].astype(np.uint8)
                    elif mx < np.iinfo(np.uint16).max:
                        df[col] = df[col].astype(np.uint16)
                    elif mx < np.iinfo(np.uint32).max:
                        df[col] = df[col].astype(np.uint32)
                    elif mx < np.iinfo(np.uint64).max:
                        df[col] = df[col].astype(np.uint64)
                else:
                    if mn > np.iinfo(np.int8).min and mx < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int8)
                    elif mn > np.iinfo(np.int16).min and mx < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int16)
                    elif mn > np.iinfo(np.int32).min and mx < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif mn > np.iinfo(np.int64).min and mx < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)
            if df[col].dtype == float:
                df[col] =df[col].astype(np.float32)
    
    red_memory = df.memory_usage().sum()/1024**2
    print('Memory usage after complition: ',red_memory,'MB')

# %% [markdown]
# ## 2.0 Exploratory data analysis
# Glimpse dataset

# %%
train.head()
# Out:
#         date  store  item  sales
# 0 2013-01-01      1     1     13
# 1 2013-01-02      1     1     11
# 2 2013-01-03      1     1     14
# 3 2013-01-04      1     1     13
# 4 2013-01-05      1     1     10

# %%
test.head()
# Out:
#    id       date  store  item
# 0   0 2018-01-01      1     1
# 1   1 2018-01-02      1     1
# 2   2 2018-01-03      1     1
# 3   3 2018-01-04      1     1
# 4   4 2018-01-05      1     1

# %% [markdown]
# The test dataset contains id column but train dataset does not contains id column. While importing dataset parse_date is assigned with perticular column index.

# %%
basic_details(test) # test dataset
# Out:
#        Missing value  % Missing value           dtype  N unique
# id                 0              0.0           int64     45000
# date               0              0.0  datetime64[ns]        90
# store              0              0.0           int64        10
# item               0              0.0           int64        50

# %%
train.describe() # descriptive statistics about features
# Out:
#                store           item          sales
# count  913000.000000  913000.000000  913000.000000
# mean        5.500000      25.500000      52.250287
# std         2.872283      14.430878      28.801144
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      30.000000
# 50%         5.500000      25.500000      47.000000
# 75%         8.000000      38.000000      70.000000
# max        10.000000      50.000000     231.000000

# %% [markdown]
# There are 50 diffirent item in 10 diffirent stores. The maximum number of items sold is 231 and average item sold is 52.25.

# %% [markdown]
# ### 2.1 Date
# Let's extract day, week, month, year from date feature

# %%
print('Time series start time: "{}" and end time: "{}"'.format(train['date'].min(), train['date'].max()))
print('Time series start time: "{}" and end time: "{}"'.format(test['date'].min(), test['date'].max()))
# Out:
# Time series start time: "2013-01-01 00:00:00" and end time: "2017-12-31 00:00:00"
# Time series start time: "2018-01-01 00:00:00" and end time: "2018-03-31 00:00:00"

# %%
# Generate date time feature
date_time_feat(train,'date')
date_time_feat(test,'date')
train.head()
# Out:
#         date  store  item     ...      is_month_end  is_month_start  weekofyear
# 0 2013-01-01      1     1     ...                 0               1           1
# 1 2013-01-02      1     1     ...                 0               0           1
# 2 2013-01-03      1     1     ...                 0               0           1
# 3 2013-01-04      1     1     ...                 0               0           1
# 4 2013-01-05      1     1     ...                 0               0           1
#
# [5 rows x 11 columns]

# %%
plt.figure(figsize=(14,4))
train.set_index('date')['sales'].plot(kind='line')

# %% [markdown]
# ### 2.1 Sales

# %%
f,ax = plt.subplots(1,3,figsize=(14,4))
sns.distplot(train['sales'],ax =ax[0])
sns.distplot(np.log(train['sales']+1),ax=ax[1], color='b')
sns.boxenplot(train['sales'],ax =ax[2])
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
(train
 .groupby(['year',])
 .agg({'sales':['sum',]})
 .unstack()
 .plot(kind='bar',cmap='viridis'))

# %%
(train
 .groupby(['month','year'])
 .agg({'sales':'mean'})
 .unstack()
 .plot(figsize=(14,5)))

# %%
(train
 .groupby(['dayofweek','year'])
 .agg({'sales':'mean'})
 .unstack()
 .plot(figsize=(14,5)))

# %%
(train
.groupby(['day'])
.agg({'sales':['mean','max']})
.plot(figsize=(14,4),kind='bar',stacked=True,cmap='coolwarm'))

# %% [markdown]
# ### 2.2 Aggregate sales statistics by day

# %%
agg_stats(train,statistics=['mean','sum','min','max', 'var', 'count'],groupby_column=['day'])

# %%
(train.groupby('month')
.agg({'sales':['min','mean','max']})
 .plot(figsize=(14,4),kind='bar',stacked=True))

# %%
agg_stats(train,statistics=['mean','sum','min','max', 'var', 'count'],groupby_column=['month'])

# %% [markdown]
# ### 2.3 Store

# %%
(train
 .groupby(['store','month'])
 .agg({'sales':['sum']})
 .unstack()
 .plot(figsize=(14,3),kind='box',stacked=True,cmap='viridis'))
plt.xticks(rotation=90);

# %%
(train
 .groupby(['store','dayofweek'])
 .agg({'sales':['sum']})
 .unstack()
 .plot(figsize=(14,3),kind='box',stacked=True,cmap='viridis'))
plt.xticks(rotation=90);

# %%
(train
 .groupby(['store','year'])
 .agg({'sales':['sum']})
 .unstack()
 .plot(figsize=(14,3),kind='box',stacked=True,cmap='viridis'))
plt.xticks(rotation=90);

# %%
(train
 .groupby('store')
 .agg({'sales':['min','mean','max']})
 .plot(figsize=(14,4),kind='bar',stacked=True,cmap='magma'))

# %%
agg_stats(train,statistics=['mean','sum','min','max', 'var', 'count'],groupby_column=['store'])

# %% [markdown]
# ### 2.4 item

# %%
(train
 .groupby('item')
 .agg({'sales':['min','mean','max']})
 .plot(figsize=(14,4),kind='bar',stacked=True,cmap='viridis'))

# %%
agg_stats(train,statistics=['mean','sum','min','max', 'var', 'count'],groupby_column=['item'])

# %%
(train
 .groupby(['item','month'])
 .agg({'sales':['sum']})
 .unstack()
 .plot(figsize=(14,4),kind='box',stacked=True,cmap='magma'))
plt.xticks(rotation=90);

# %%
(train
 .groupby(['item','store'])
 .agg({'sales':'mean'})
 .unstack()
 .plot(figsize=(14,5),kind='line'))
plt.savefig('agg.png')

# %%
train1 =train.copy()
train1['month'] = train1['date'].dt.month_name()
plt.figure(figsize=(14,6))
pd.plotting.parallel_coordinates(train1[['dayofweek','store','sales','item','month']][:1000]
                                 ,'month',colormap='rainbow')
del train1

# %% [markdown]
# ### 2.5 Rolling window

# %%
plt.figure(figsize=(14,5))
train['sales'].head(1000).plot(color='darkgray')
train['sales'].head(1000).rolling(window=12).mean().plot(label='mean')
#train['sales'].head(1000).rolling(window=12).median().plot(label='median')
train['sales'].head(1000).rolling(window=7).min().plot(label='min',color='g')
train['sales'].head(1000).rolling(window=7).max().plot(label='max',color='b')
train['sales'].head(1000).rolling(window=7).std().plot(label='std',color='yellow')
plt.legend()
#plt.savefig('Rolling window.png')

# %% [markdown]
# ### 2.6 Expanding window

# %%
# Expanding window
plt.figure(figsize=(14,5))
train['sales'].head(1000).plot(color='darkgray')
train['sales'].head(1000).expanding().mean().plot(label='mean')
#train['sales'].head(1000).rolling(window=12).median().plot(label='median')
train['sales'].head(1000).expanding().min().plot(label='min',color='g')
train['sales'].head(1000).expanding().max().plot(label='max',color='b')
train['sales'].head(1000).expanding().std().plot(label='std',color='yellow')
plt.legend()

# %% [markdown]
# ## 3.0 Data preprocessing

# %% [markdown]
# ### 3.0 Aggregate / Rolling function

# %%
# Claculate groupby statics for lag date 
def calc_stats(df, end,window,groupby=None,aggregates='mean',value='sales'):
    
    # dates
    last_date = pd.to_datetime(end) - pd.Timedelta(days=1)
    first_date = pd.to_datetime(end) - pd.Timedelta(days= window)
    # Aggregate
    df1 = df[(df.date >=first_date) & (df.date<= last_date) ]
    df_agg = df1.groupby(groupby)[value].agg(aggregates)
    # Change name of columns
    df_agg.name =  str(end).split(' ')[0]+'_' + '_'.join(groupby)+'_'+aggregates+'_'+ str(window)
    return df_agg.reset_index()

#sales_by_store_item
def sales_by_store_item(df, end, aggregates='mean', value='sales'):
    
    print('Adding sales by store item')
    data = calc_stats(df,end, window=1,aggregates=aggregates, 
                      groupby=['store','item'], value=value)
    print('window 1 added')
    
    for window in  [3,7,14,28,90,180,365]:
        agg = calc_stats(df,end, window=window, aggregates=aggregates,
                         groupby=['store','item'], value=value )
        data = pd.merge(data,agg)
        print('window %d added'% window)
    return data

# sales by store item dayofweek
def sales_by_store_item_dayofweek(df, end, aggregates='mean', value='sales'):
    
    print('Adding sales by store item dayofweek')
    data = calc_stats(df,end, window=7, aggregates=aggregates,
                      groupby = ['store','item','dayofweek'], value=value)
    print('window 7 added')
    
    for window in  [14,28,28*2,28*3,28*6,28*12]:
        agg = calc_stats(df,end, window=window, aggregates=aggregates,
                         groupby=['store','item','dayofweek'], value=value )
        data = pd.merge(data,agg)
        print('window %d added'% window)
    return data

# sales_by_store_item_day
def sales_by_store_item_day(df, end, aggregates='mean', value='sales'):
    
    print('Adding sales by store item day')
    data = calc_stats(df,end, window=365, aggregates=aggregates,
                      groupby = ['store','item','day'], value=value)
    print('window 365 added')
    
    return data

# Sales by item
def sales_by_item(df, end, aggregates='mean', value='sales'):
    
    print('Adding sales by item ')
    data = calc_stats(df,end, window=7, aggregates=aggregates,
                      groupby = ['item'], value=value)
    print('window 7 added')
    
    for window in  [14,28,28*2]:
        agg = calc_stats(df,end, window=window, aggregates=aggregates,
                         groupby=['item'], value=value )
        data = pd.merge(data,agg)
        print('window %d added'% window)
    return data

# %%
def calc_roll_stat(df,end,groupby=None,window=1,aggregate='mean'):
    # Rolling statistics method
    last_date = pd.to_datetime(end) - pd.Timedelta(days=1)
    first_date = pd.to_datetime(end) - pd.Timedelta(days=window)
    df1 = df[(df.date >= first_date) & (df.date <= last_date)]
    
    dfPivot = df1.set_index(['date']+groupby)['sales'].unstack().unstack()
    dfPivot = dfPivot.rolling(window=window).mean().fillna(method='bfill')
    return dfPivot.stack().stack().rename(aggregate+str(window))

def calc_expand_stat(df,end,window=1,aggregate='mean'):
    # Expanding statistics method
    last_date = pd.to_datetime(end) - pd.Timedelta(days=1)
    first_date = pd.to_datetime(end) - pd.Timedelta(days=window)
    df1 = df[(df.date >= first_date) & (df.date <= last_date)]
    
    dfPivot = df1.set_index(['date','store','item'])['sales'].unstack().unstack()
    dfPivot = dfPivot.expanding(min_periods=window).mean().fillna(method='bfill')
    dfPivot = dfPivot.stack().stack().rename(aggregate+'_'+str(window)).reset_index()
    return dfPivot

def sales_by_store_item_expading(df,end,aggregate = 'mean', value = 'sales'):
    print('Adding sales by expanding')
    data =calc_expand_stat(df,end,window=3, aggregate='mean')
    return data
# https://stackoverflow.com/questions/25917287/pandas-groupby-expanding-mean-by-column-value

# %%
def create_data1(sales,test,date):
    
    # Date input
    for i in range(2):
        end = pd.to_datetime(date) - pd.Timedelta(days=7*i+1)
        print(end)
    
        # Rolling feature
        #for aggregates in ['mean','min','max','sum','std']:
        for aggregates in ['mean','sum']:

            # store/item
            print('-'*20+'Aggregate by '+aggregates+'-'*20)
            data = sales_by_store_item(sales,end, aggregates=aggregates,value='sales')
            sales = pd.merge(sales,data,on=['store','item'],how='left')
            test = pd.merge(test,data,on=['store','item'], how='left')

            # store/item/dayofweek
            df = sales_by_store_item_dayofweek(sales,end, aggregates=aggregates,value='sales')
            #data = pd.merge(data,df,)
            sales = pd.merge(sales,df,on=['store','item','dayofweek'],how='left')
            test = pd.merge(test,df,on=['store','item','dayofweek'], how='left')

            # store/item/day
            df = sales_by_store_item_day(sales,end, aggregates=aggregates,value='sales')
            #data = pd.merge(data,df)
            sales = pd.merge(sales,df,on=['store','item','day'],how='left')
            test = pd.merge(test,df,on=['store','item','day'], how='left')

            # sales/item
            df = sales_by_item(sales,end, aggregates=aggregates, value='sales')
            data = pd.merge(data,df)
            #data = pd.merge(sales,data)
            sales = pd.merge(sales,df, on=['item'],how='left')
            test = pd.merge(test,df, on=['item'], how='left')

    return sales,test

# %%
#Time series start time: "2013-01-01 00:00:00" and end time: "2017-12-31 00:00:00"
#Time series start time: "2018-01-01 00:00:00" and end time: "2018-03-31 00:00:00"
tes_start = '2018-01-01'

# %%
# Rolling aggregation or lag feature for diffirend window size
train1,test1 = create_data1(train,test,tes_start)
# Out:
# 2017-12-31 00:00:00
# --------------------Aggregate by mean--------------------
# Adding sales by store item
# window 1 added
# window 3 added
# window 7 added
# window 14 added
# window 28 added
# window 90 added
# window 180 added
# window 365 added
# Adding sales by store item dayofweek
# window 7 added
# window 14 added
# window 28 added
# window 56 added
# window 84 added
# window 168 added
# window 336 added
# Adding sales by store item day
# window 365 added
# Adding sales by item
# window 7 added
# window 14 added
# window 28 added
# window 56 added
# --------------------Aggregate by sum--------------------
# Adding sales by store item
# window 1 added
# window 3 added
# window 7 added
# window 14 added
# window 28 added
# window 90 added
# window 180 added
# window 365 added
# Adding sales by store item dayofweek
# window 7 added
# window 14 added
# window 28 added
# window 56 added
# window 84 added
# window 168 added
# window 336 added
# Adding sales by store item day
# window 365 added
# Adding sales by item
# window 7 added
# window 14 added
# window 28 added
# window 56 added
# 2017-12-24 00:00:00
# --------------------Aggregate by mean--------------------
# Adding sales by store item
# window 1 added
# window 3 added
# window 7 added
# window 14 added
# window 28 added
# window 90 added
# window 180 added
# window 365 added
# Adding sales by store item dayofweek
# window 7 added
# window 14 added
# window 28 added
# window 56 added
# window 84 added
# window 168 added
# window 336 added
# Adding sales by store item day
# window 365 added
# Adding sales by item
# window 7 added
# window 14 added
# window 28 added
# window 56 added
# --------------------Aggregate by sum--------------------
# Adding sales by store item
# window 1 added
# window 3 added
# window 7 added
# window 14 added
# window 28 added
# window 90 added
# window 180 added
# window 365 added
# Adding sales by store item dayofweek
# window 7 added
# window 14 added
# window 28 added
# window 56 added
# window 84 added
# window 168 added
# window 336 added
# Adding sales by store item day
# window 365 added
# Adding sales by item
# window 7 added
# window 14 added
# window 28 added
# window 56 added

# %% [markdown]
# ### 3.1 One hot encoding

# %%
train1['id'] = np.nan
train1['is_train'] = True
test1['is_train'] = False
test1['sales'] = np.nan

# concat train,test
train_test = pd.concat([train1,test1],axis=0)

#Log transform
train_test['sales_log'] = np.log(train_test['sales']+1)
gc.collect()
train_test.shape

def one_hot_encoding(df,columns):
    print('Original shape',df.shape)
    df = pd.get_dummies(df,drop_first=True,columns=columns)
    print('After OHE', df.shape)
    return df
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys

# %%
gc.collect()
train_test = one_hot_encoding(train_test,columns=['month','dayofweek'])
# Out:
# Original shape (958000, 94)
# After OHE (958000, 109)

# %%
reduce_memory_usage(train_test)
# Out:
# Intial memory usage: 676.0787963867188 MB
# Memory usage after complition:  252.15911865234375 MB

# %%
#plt.figure(figsize=(14,10))
#sns.heatmap(train_test1.corr(), cmap='coolwarm', annot=True,fmt='.2f')

# %% [markdown]
# ## 4.0 Model selection

# %%
# Model
col_drop = ['id','is_train','sales','sales_log']
X = train_test[train_test['is_train'] == True].drop(col_drop, axis=1)
y = train_test[train_test['is_train'] == True]['sales_log']
test_new = train_test[train_test['is_train'] == False].drop(col_drop +['date'],axis=1)

# Time series based split
#Time series start time: "2013-01-01 00:00:00" and end time: "2017-12-31 00:00:00"
#Time series start time: "2018-01-01 00:00:00" and end time: "2018-03-31 00:00:00"
tra_start, tra_end = '2013-01-01','2016-12-31'
val_start, val_end = '2017-01-01','2017-12-31'
tes_start = '2018-01-01'

X_train = X[X.date.isin(pd.date_range(tra_start,tra_end))].drop(['date'],axis=1)
X_valid = X[X.date.isin(pd.date_range(val_start, val_end))].drop(['date'],axis=1)
y_train = y[X.date.isin(pd.date_range(tra_start,tra_end))]
y_valid = y[X.date.isin(pd.date_range(val_start, val_end))]
gc.collect()
X.shape,test_new.shape
# Out:
# ((913000, 105), (45000, 104))

# %%
# SMAPE Systematic mean absolute Persent error
def smape(y_true,y_pred):
    
    n = len(y_pred)
    masked_arr = ~((y_pred==0)&(y_true==0))
    y_pred, y_true = y_pred[masked_arr], y_true[masked_arr]
    nom = np.abs(y_true - y_pred)
    denom = np.abs(y_true) + np.abs(y_pred)
    smape = 200/n * np.sum(nom/denom)
    return smape
def lgb_smape(pred,train_data):
    ''' 
    Custom evaluvation function
    '''
    label = train_data.get_label()
    smape_val = smape(np.expm1(pred), np.expm1(label))
    return 'SMAPE',smape_val, False

# %% [markdown]
# ## 5.0 Model

# %%
def lgb_model(X_train, X_valid, y_valid, y_test,test_new):
    lgb_param = {}
    lgb_param['boosting_type'] ='gbdt'
    lgb_param['max_depth'] = 7
    lgb_param['num_leaves'] = 2**7
    lgb_param['learning_rate'] = 0.05
    #lgb_param['n_estimators'] = 3000
    lgb_param['feature_fraction'] = 0.9
    lgb_param['bagging_fraction'] = 0.9
    lgb_param['lambda_l1'] = 0.06
    lgb_param['lambda_l2'] =  0.1
    lgb_param['random_state'] = seed
    lgb_param['n_jobs'] = 4
    lgb_param['silent'] = -1
    lgb_param['verbose'] = -1
    lgb_param['metric'] = 'mae'
    
    model = lgb.LGBMRegressor(**lgb_param)
    lgb_train = lgb.Dataset(X_train,y_train)
    lgb_valid = lgb.Dataset(X_valid,y_valid)
    valid_set = [lgb_train,lgb_valid]
    model = lgb.train(params=lgb_param,train_set=lgb_train,valid_sets=valid_set,num_boost_round= 300,
                      feval=lgb_smape,early_stopping_rounds=20,)
    print('-'*10,'*'*20,'-'*10)
    #model.fit(X_train,y_train, eval_set= [(X_train,y_train),(X_valid,y_valid)],
    #          eval_metric ='rmse',early_stopping_rounds=20,verbose=100)
    
    y_pred = model.predict(X_valid)
    print('Root mean_squared_error','-'*20 ,np.sqrt(mean_squared_error(y_valid, y_pred)))
    y_pred_new = model.predict(test_new)
    return y_pred_new, model

# %%
# Model training
y_pred_new, model = lgb_model(X_train, X_valid, y_valid, y_valid,test_new)
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:661: UserWarning: silent keyword has been found in `params` and will be ignored. Please use silent argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# [1]	training's l1: 0.449893	training's SMAPE: 44.0849	valid_1's l1: 0.467498	valid_1's SMAPE: 45.711
# Training until validation scores don't improve for 20 rounds.
# [2]	training's l1: 0.430474	training's SMAPE: 42.3272	valid_1's l1: 0.448112	valid_1's SMAPE: 43.9569
# [3]	training's l1: 0.411188	training's SMAPE: 40.5679	valid_1's l1: 0.429167	valid_1's SMAPE: 42.2304
# [4]	training's l1: 0.39296	training's SMAPE: 38.8902	valid_1's l1: 0.411211	valid_1's SMAPE: 40.5798
# [5]	training's l1: 0.375866	training's SMAPE: 37.304	valid_1's l1: 0.394554	valid_1's SMAPE: 39.0381
# [6]	training's l1: 0.359594	training's SMAPE: 35.7834	valid_1's l1: 0.378516	valid_1's SMAPE: 37.5408
# [7]	training's l1: 0.344179	training's SMAPE: 34.3329	valid_1's l1: 0.363232	valid_1's SMAPE: 36.1039
# [8]	training's l1: 0.329515	training's SMAPE: 32.9439	valid_1's l1: 0.348612	valid_1's SMAPE: 34.7227
# [9]	training's l1: 0.315687	training's SMAPE: 31.6265	valid_1's l1: 0.33483	valid_1's SMAPE: 33.4114
# [10]	training's l1: 0.303556	training's SMAPE: 30.464	valid_1's l1: 0.322376	valid_1's SMAPE: 32.219
# [11]	training's l1: 0.291255	training's SMAPE: 29.2808	valid_1's l1: 0.310333	valid_1's SMAPE: 31.0642
# [12]	training's l1: 0.279676	training's SMAPE: 28.1622	valid_1's l1: 0.298513	valid_1's SMAPE: 29.9256
# [13]	training's l1: 0.268754	training's SMAPE: 27.1026	valid_1's l1: 0.287225	valid_1's SMAPE: 28.834
# [14]	training's l1: 0.258475	training's SMAPE: 26.1016	valid_1's l1: 0.277149	valid_1's SMAPE: 27.8553
# [15]	training's l1: 0.249431	training's SMAPE: 25.2181	valid_1's l1: 0.267759	valid_1's SMAPE: 26.941
# [16]	training's l1: 0.240497	training's SMAPE: 24.3429	valid_1's l1: 0.257935	valid_1's SMAPE: 25.9809
# [17]	training's l1: 0.232012	training's SMAPE: 23.5091	valid_1's l1: 0.249615	valid_1's SMAPE: 25.1668
# [18]	training's l1: 0.224077	training's SMAPE: 22.7275	valid_1's l1: 0.241401	valid_1's SMAPE: 24.3607
# [19]	training's l1: 0.217104	training's SMAPE: 22.039	valid_1's l1: 0.234364	valid_1's SMAPE: 23.6685
# [20]	training's l1: 0.210184	training's SMAPE: 21.3544	valid_1's l1: 0.226845	valid_1's SMAPE: 22.9272
# [21]	training's l1: 0.203695	training's SMAPE: 20.7113	valid_1's l1: 0.220539	valid_1's SMAPE: 22.3044
# [22]	training's l1: 0.197667	training's SMAPE: 20.1126	valid_1's l1: 0.214024	valid_1's SMAPE: 21.6595
# [23]	training's l1: 0.192051	training's SMAPE: 19.5541	valid_1's l1: 0.207939	valid_1's SMAPE: 21.0571
# [24]	training's l1: 0.186924	training's SMAPE: 19.0436	valid_1's l1: 0.203123	valid_1's SMAPE: 20.5797
# [25]	training's l1: 0.18205	training's SMAPE: 18.5576	valid_1's l1: 0.198018	valid_1's SMAPE: 20.0729
# [26]	training's l1: 0.177525	training's SMAPE: 18.1059	valid_1's l1: 0.193116	valid_1's SMAPE: 19.5858
# [27]	training's l1: 0.173338	training's SMAPE: 17.6874	valid_1's l1: 0.188692	valid_1's SMAPE: 19.1456
# [28]	training's l1: 0.169495	training's SMAPE: 17.303	valid_1's l1: 0.184524	valid_1's SMAPE: 18.7305
# [29]	training's l1: 0.165931	training's SMAPE: 16.9462	valid_1's l1: 0.180695	valid_1's SMAPE: 18.3491
# [30]	training's l1: 0.162637	training's SMAPE: 16.6163	valid_1's l1: 0.176866	valid_1's SMAPE: 17.9672
# [31]	training's l1: 0.15957	training's SMAPE: 16.3089	valid_1's l1: 0.173372	valid_1's SMAPE: 17.6186
# [32]	training's l1: 0.156743	training's SMAPE: 16.0253	valid_1's l1: 0.170053	valid_1's SMAPE: 17.287
# [33]	training's l1: 0.154206	training's SMAPE: 15.7708	valid_1's l1: 0.167578	valid_1's SMAPE: 17.0401
# [34]	training's l1: 0.151805	training's SMAPE: 15.5298	valid_1's l1: 0.16477	valid_1's SMAPE: 16.7597
# [35]	training's l1: 0.14959	training's SMAPE: 15.3074	valid_1's l1: 0.161968	valid_1's SMAPE: 16.4795
# [36]	training's l1: 0.147545	training's SMAPE: 15.102	valid_1's l1: 0.159491	valid_1's SMAPE: 16.2318
# [37]	training's l1: 0.145675	training's SMAPE: 14.9141	valid_1's l1: 0.157118	valid_1's SMAPE: 15.9944
# [38]	training's l1: 0.144022	training's SMAPE: 14.7479	valid_1's l1: 0.155446	valid_1's SMAPE: 15.8274
# [39]	training's l1: 0.142423	training's SMAPE: 14.5872	valid_1's l1: 0.153209	valid_1's SMAPE: 15.6035
# [40]	training's l1: 0.140956	training's SMAPE: 14.4398	valid_1's l1: 0.151334	valid_1's SMAPE: 15.4156
# [41]	training's l1: 0.139659	training's SMAPE: 14.3093	valid_1's l1: 0.149981	valid_1's SMAPE: 15.2804
# [42]	training's l1: 0.138407	training's SMAPE: 14.1835	valid_1's l1: 0.148072	valid_1's SMAPE: 15.0892
# [43]	training's l1: 0.137265	training's SMAPE: 14.0686	valid_1's l1: 0.146524	valid_1's SMAPE: 14.9342
# [44]	training's l1: 0.136203	training's SMAPE: 13.9618	valid_1's l1: 0.144817	valid_1's SMAPE: 14.763
# [45]	training's l1: 0.13524	training's SMAPE: 13.865	valid_1's l1: 0.143424	valid_1's SMAPE: 14.6235
# [46]	training's l1: 0.134362	training's SMAPE: 13.7767	valid_1's l1: 0.141992	valid_1's SMAPE: 14.4799
# [47]	training's l1: 0.133553	training's SMAPE: 13.6953	valid_1's l1: 0.140718	valid_1's SMAPE: 14.3522
# [48]	training's l1: 0.132807	training's SMAPE: 13.6204	valid_1's l1: 0.139527	valid_1's SMAPE: 14.2328
# [49]	training's l1: 0.132125	training's SMAPE: 13.5518	valid_1's l1: 0.138405	valid_1's SMAPE: 14.1203
# [50]	training's l1: 0.13149	training's SMAPE: 13.488	valid_1's l1: 0.137334	valid_1's SMAPE: 14.013
# [51]	training's l1: 0.130918	training's SMAPE: 13.4305	valid_1's l1: 0.136274	valid_1's SMAPE: 13.9067
# [52]	training's l1: 0.130394	training's SMAPE: 13.3777	valid_1's l1: 0.135284	valid_1's SMAPE: 13.8073
# [53]	training's l1: 0.129909	training's SMAPE: 13.329	valid_1's l1: 0.134487	valid_1's SMAPE: 13.7275
# [54]	training's l1: 0.129512	training's SMAPE: 13.2891	valid_1's l1: 0.13401	valid_1's SMAPE: 13.6798
# [55]	training's l1: 0.129107	training's SMAPE: 13.2485	valid_1's l1: 0.133148	valid_1's SMAPE: 13.5933
# [56]	training's l1: 0.128729	training's SMAPE: 13.2106	valid_1's l1: 0.132427	valid_1's SMAPE: 13.5209
# [57]	training's l1: 0.128376	training's SMAPE: 13.175	valid_1's l1: 0.131663	valid_1's SMAPE: 13.4444
# [58]	training's l1: 0.128073	training's SMAPE: 13.1447	valid_1's l1: 0.130989	valid_1's SMAPE: 13.3767
# [59]	training's l1: 0.127785	training's SMAPE: 13.1158	valid_1's l1: 0.130389	valid_1's SMAPE: 13.3165
# [60]	training's l1: 0.127517	training's SMAPE: 13.0889	valid_1's l1: 0.129852	valid_1's SMAPE: 13.2627
# [61]	training's l1: 0.127264	training's SMAPE: 13.0636	valid_1's l1: 0.12931	valid_1's SMAPE: 13.2083
# [62]	training's l1: 0.127038	training's SMAPE: 13.0408	valid_1's l1: 0.128792	valid_1's SMAPE: 13.1563
# [63]	training's l1: 0.126833	training's SMAPE: 13.0203	valid_1's l1: 0.128281	valid_1's SMAPE: 13.105
# [64]	training's l1: 0.126644	training's SMAPE: 13.0014	valid_1's l1: 0.127872	valid_1's SMAPE: 13.064
# [65]	training's l1: 0.126472	training's SMAPE: 12.9842	valid_1's l1: 0.127446	valid_1's SMAPE: 13.0213
# [66]	training's l1: 0.126316	training's SMAPE: 12.9685	valid_1's l1: 0.127053	valid_1's SMAPE: 12.9819
# [67]	training's l1: 0.126167	training's SMAPE: 12.9536	valid_1's l1: 0.126755	valid_1's SMAPE: 12.952
# [68]	training's l1: 0.126031	training's SMAPE: 12.9401	valid_1's l1: 0.126361	valid_1's SMAPE: 12.9124
# [69]	training's l1: 0.125909	training's SMAPE: 12.9279	valid_1's l1: 0.126015	valid_1's SMAPE: 12.8777
# [70]	training's l1: 0.125798	training's SMAPE: 12.9168	valid_1's l1: 0.125727	valid_1's SMAPE: 12.8488
# [71]	training's l1: 0.125696	training's SMAPE: 12.9066	valid_1's l1: 0.125473	valid_1's SMAPE: 12.8234
# [72]	training's l1: 0.125594	training's SMAPE: 12.8964	valid_1's l1: 0.125162	valid_1's SMAPE: 12.7921
# [73]	training's l1: 0.125506	training's SMAPE: 12.8877	valid_1's l1: 0.124911	valid_1's SMAPE: 12.767
# [74]	training's l1: 0.125429	training's SMAPE: 12.88	valid_1's l1: 0.124658	valid_1's SMAPE: 12.7416
# [75]	training's l1: 0.125352	training's SMAPE: 12.8723	valid_1's l1: 0.124451	valid_1's SMAPE: 12.7208
# [76]	training's l1: 0.12528	training's SMAPE: 12.8651	valid_1's l1: 0.12423	valid_1's SMAPE: 12.6987
# [77]	training's l1: 0.125214	training's SMAPE: 12.8585	valid_1's l1: 0.124012	valid_1's SMAPE: 12.6768
# [78]	training's l1: 0.125153	training's SMAPE: 12.8525	valid_1's l1: 0.123831	valid_1's SMAPE: 12.6587
# [79]	training's l1: 0.125099	training's SMAPE: 12.8471	valid_1's l1: 0.123657	valid_1's SMAPE: 12.6412
# [80]	training's l1: 0.125045	training's SMAPE: 12.8417	valid_1's l1: 0.123514	valid_1's SMAPE: 12.6269
# [81]	training's l1: 0.124996	training's SMAPE: 12.8369	valid_1's l1: 0.123352	valid_1's SMAPE: 12.6107
# [82]	training's l1: 0.124954	training's SMAPE: 12.8327	valid_1's l1: 0.123201	valid_1's SMAPE: 12.5955
# [83]	training's l1: 0.124914	training's SMAPE: 12.8287	valid_1's l1: 0.123072	valid_1's SMAPE: 12.5825
# [84]	training's l1: 0.124878	training's SMAPE: 12.8252	valid_1's l1: 0.122941	valid_1's SMAPE: 12.5695
# [85]	training's l1: 0.124841	training's SMAPE: 12.8215	valid_1's l1: 0.122807	valid_1's SMAPE: 12.556
# [86]	training's l1: 0.12481	training's SMAPE: 12.8184	valid_1's l1: 0.122754	valid_1's SMAPE: 12.5508
# [87]	training's l1: 0.124775	training's SMAPE: 12.8149	valid_1's l1: 0.122628	valid_1's SMAPE: 12.5381
# [88]	training's l1: 0.124743	training's SMAPE: 12.8118	valid_1's l1: 0.122511	valid_1's SMAPE: 12.5264
# [89]	training's l1: 0.124715	training's SMAPE: 12.809	valid_1's l1: 0.12241	valid_1's SMAPE: 12.5163
# [90]	training's l1: 0.124686	training's SMAPE: 12.8061	valid_1's l1: 0.122361	valid_1's SMAPE: 12.5114
# [91]	training's l1: 0.124663	training's SMAPE: 12.8039	valid_1's l1: 0.122263	valid_1's SMAPE: 12.5016
# [92]	training's l1: 0.124638	training's SMAPE: 12.8014	valid_1's l1: 0.122165	valid_1's SMAPE: 12.4917
# [93]	training's l1: 0.124615	training's SMAPE: 12.799	valid_1's l1: 0.122059	valid_1's SMAPE: 12.481
# [94]	training's l1: 0.124594	training's SMAPE: 12.797	valid_1's l1: 0.121987	valid_1's SMAPE: 12.4738
# [95]	training's l1: 0.124573	training's SMAPE: 12.7949	valid_1's l1: 0.121893	valid_1's SMAPE: 12.4644
# [96]	training's l1: 0.124557	training's SMAPE: 12.7933	valid_1's l1: 0.121812	valid_1's SMAPE: 12.4562
# [97]	training's l1: 0.124536	training's SMAPE: 12.7913	valid_1's l1: 0.12175	valid_1's SMAPE: 12.4501
# [98]	training's l1: 0.124517	training's SMAPE: 12.7893	valid_1's l1: 0.121671	valid_1's SMAPE: 12.4421
# [99]	training's l1: 0.124502	training's SMAPE: 12.7878	valid_1's l1: 0.121618	valid_1's SMAPE: 12.4368
# [100]	training's l1: 0.124485	training's SMAPE: 12.7862	valid_1's l1: 0.121547	valid_1's SMAPE: 12.4296
# [101]	training's l1: 0.124466	training's SMAPE: 12.7843	valid_1's l1: 0.121527	valid_1's SMAPE: 12.4277
# [102]	training's l1: 0.12445	training's SMAPE: 12.7827	valid_1's l1: 0.121458	valid_1's SMAPE: 12.4208
# [103]	training's l1: 0.124435	training's SMAPE: 12.7812	valid_1's l1: 0.1214	valid_1's SMAPE: 12.4149
# [104]	training's l1: 0.124421	training's SMAPE: 12.7799	valid_1's l1: 0.121382	valid_1's SMAPE: 12.4132
# [105]	training's l1: 0.124409	training's SMAPE: 12.7786	valid_1's l1: 0.121341	valid_1's SMAPE: 12.409
# [106]	training's l1: 0.124396	training's SMAPE: 12.7774	valid_1's l1: 0.121295	valid_1's SMAPE: 12.4044
# [107]	training's l1: 0.124382	training's SMAPE: 12.7759	valid_1's l1: 0.121251	valid_1's SMAPE: 12.4
# [108]	training's l1: 0.124371	training's SMAPE: 12.7749	valid_1's l1: 0.121205	valid_1's SMAPE: 12.3953
# [109]	training's l1: 0.124359	training's SMAPE: 12.7737	valid_1's l1: 0.121166	valid_1's SMAPE: 12.3914
# [110]	training's l1: 0.124348	training's SMAPE: 12.7726	valid_1's l1: 0.121109	valid_1's SMAPE: 12.3858
# [111]	training's l1: 0.124336	training's SMAPE: 12.7714	valid_1's l1: 0.121083	valid_1's SMAPE: 12.3831
# [112]	training's l1: 0.124323	training's SMAPE: 12.7701	valid_1's l1: 0.121049	valid_1's SMAPE: 12.3797
# [113]	training's l1: 0.124313	training's SMAPE: 12.769	valid_1's l1: 0.121007	valid_1's SMAPE: 12.3756
# [114]	training's l1: 0.124302	training's SMAPE: 12.768	valid_1's l1: 0.120966	valid_1's SMAPE: 12.3714
# [115]	training's l1: 0.124287	training's SMAPE: 12.7664	valid_1's l1: 0.120954	valid_1's SMAPE: 12.3702
# [116]	training's l1: 0.124278	training's SMAPE: 12.7656	valid_1's l1: 0.12092	valid_1's SMAPE: 12.3668
# [117]	training's l1: 0.124266	training's SMAPE: 12.7644	valid_1's l1: 0.120904	valid_1's SMAPE: 12.3652
# [118]	training's l1: 0.124256	training's SMAPE: 12.7634	valid_1's l1: 0.120862	valid_1's SMAPE: 12.361
# [119]	training's l1: 0.124248	training's SMAPE: 12.7626	valid_1's l1: 0.120848	valid_1's SMAPE: 12.3595
# [120]	training's l1: 0.124239	training's SMAPE: 12.7617	valid_1's l1: 0.12081	valid_1's SMAPE: 12.3557
# [121]	training's l1: 0.124226	training's SMAPE: 12.7603	valid_1's l1: 0.120798	valid_1's SMAPE: 12.3545
# [122]	training's l1: 0.124217	training's SMAPE: 12.7595	valid_1's l1: 0.120778	valid_1's SMAPE: 12.3525
# [123]	training's l1: 0.124207	training's SMAPE: 12.7585	valid_1's l1: 0.120752	valid_1's SMAPE: 12.3499
# [124]	training's l1: 0.124198	training's SMAPE: 12.7576	valid_1's l1: 0.120719	valid_1's SMAPE: 12.3465
# [125]	training's l1: 0.12419	training's SMAPE: 12.7568	valid_1's l1: 0.120702	valid_1's SMAPE: 12.3448
# [126]	training's l1: 0.124181	training's SMAPE: 12.7559	valid_1's l1: 0.12067	valid_1's SMAPE: 12.3417
# [127]	training's l1: 0.124174	training's SMAPE: 12.7552	valid_1's l1: 0.120659	valid_1's SMAPE: 12.3405
# [128]	training's l1: 0.124164	training's SMAPE: 12.7542	valid_1's l1: 0.120634	valid_1's SMAPE: 12.3381
# [129]	training's l1: 0.124152	training's SMAPE: 12.7529	valid_1's l1: 0.120625	valid_1's SMAPE: 12.3371
# [130]	training's l1: 0.124142	training's SMAPE: 12.752	valid_1's l1: 0.120604	valid_1's SMAPE: 12.3351
# [131]	training's l1: 0.124135	training's SMAPE: 12.7513	valid_1's l1: 0.120589	valid_1's SMAPE: 12.3336
# [132]	training's l1: 0.124125	training's SMAPE: 12.7503	valid_1's l1: 0.120556	valid_1's SMAPE: 12.3302
# [133]	training's l1: 0.124115	training's SMAPE: 12.7493	valid_1's l1: 0.120549	valid_1's SMAPE: 12.3295
# [134]	training's l1: 0.124106	training's SMAPE: 12.7484	valid_1's l1: 0.120535	valid_1's SMAPE: 12.3281
# [135]	training's l1: 0.124101	training's SMAPE: 12.7479	valid_1's l1: 0.120526	valid_1's SMAPE: 12.3272
# [136]	training's l1: 0.124092	training's SMAPE: 12.7469	valid_1's l1: 0.120523	valid_1's SMAPE: 12.3269
# [137]	training's l1: 0.124085	training's SMAPE: 12.7463	valid_1's l1: 0.120495	valid_1's SMAPE: 12.3241
# [138]	training's l1: 0.12408	training's SMAPE: 12.7457	valid_1's l1: 0.120488	valid_1's SMAPE: 12.3234
# [139]	training's l1: 0.12407	training's SMAPE: 12.7447	valid_1's l1: 0.120486	valid_1's SMAPE: 12.3231
# [140]	training's l1: 0.124058	training's SMAPE: 12.7435	valid_1's l1: 0.120482	valid_1's SMAPE: 12.3227
# [141]	training's l1: 0.124052	training's SMAPE: 12.743	valid_1's l1: 0.12046	valid_1's SMAPE: 12.3206
# [142]	training's l1: 0.124044	training's SMAPE: 12.7421	valid_1's l1: 0.120451	valid_1's SMAPE: 12.3197
# [143]	training's l1: 0.124039	training's SMAPE: 12.7416	valid_1's l1: 0.120445	valid_1's SMAPE: 12.3191
# [144]	training's l1: 0.124032	training's SMAPE: 12.7409	valid_1's l1: 0.120416	valid_1's SMAPE: 12.3161
# [145]	training's l1: 0.124022	training's SMAPE: 12.7399	valid_1's l1: 0.120415	valid_1's SMAPE: 12.316
# [146]	training's l1: 0.124018	training's SMAPE: 12.7395	valid_1's l1: 0.120412	valid_1's SMAPE: 12.3158
# [147]	training's l1: 0.124011	training's SMAPE: 12.7387	valid_1's l1: 0.120399	valid_1's SMAPE: 12.3144
# [148]	training's l1: 0.124002	training's SMAPE: 12.7378	valid_1's l1: 0.120387	valid_1's SMAPE: 12.3132
# [149]	training's l1: 0.123994	training's SMAPE: 12.737	valid_1's l1: 0.120381	valid_1's SMAPE: 12.3126
# [150]	training's l1: 0.123989	training's SMAPE: 12.7365	valid_1's l1: 0.120381	valid_1's SMAPE: 12.3126
# [151]	training's l1: 0.123982	training's SMAPE: 12.7358	valid_1's l1: 0.120376	valid_1's SMAPE: 12.3121
# [152]	training's l1: 0.123974	training's SMAPE: 12.7351	valid_1's l1: 0.120356	valid_1's SMAPE: 12.3101
# [153]	training's l1: 0.123969	training's SMAPE: 12.7345	valid_1's l1: 0.120339	valid_1's SMAPE: 12.3084
# [154]	training's l1: 0.123959	training's SMAPE: 12.7335	valid_1's l1: 0.120337	valid_1's SMAPE: 12.3082
# [155]	training's l1: 0.123952	training's SMAPE: 12.7328	valid_1's l1: 0.12033	valid_1's SMAPE: 12.3074
# [156]	training's l1: 0.123947	training's SMAPE: 12.7323	valid_1's l1: 0.120329	valid_1's SMAPE: 12.3073
# [157]	training's l1: 0.123939	training's SMAPE: 12.7315	valid_1's l1: 0.120322	valid_1's SMAPE: 12.3066
# [158]	training's l1: 0.123929	training's SMAPE: 12.7305	valid_1's l1: 0.120323	valid_1's SMAPE: 12.3067
# [159]	training's l1: 0.123919	training's SMAPE: 12.7295	valid_1's l1: 0.120322	valid_1's SMAPE: 12.3066
# [160]	training's l1: 0.123915	training's SMAPE: 12.729	valid_1's l1: 0.12032	valid_1's SMAPE: 12.3065
# [161]	training's l1: 0.123909	training's SMAPE: 12.7284	valid_1's l1: 0.120303	valid_1's SMAPE: 12.3048
# [162]	training's l1: 0.1239	training's SMAPE: 12.7275	valid_1's l1: 0.120301	valid_1's SMAPE: 12.3046
# [163]	training's l1: 0.123893	training's SMAPE: 12.7268	valid_1's l1: 0.120288	valid_1's SMAPE: 12.3032
# [164]	training's l1: 0.123883	training's SMAPE: 12.7258	valid_1's l1: 0.120283	valid_1's SMAPE: 12.3027
# [165]	training's l1: 0.123874	training's SMAPE: 12.7249	valid_1's l1: 0.120283	valid_1's SMAPE: 12.3028
# [166]	training's l1: 0.123865	training's SMAPE: 12.724	valid_1's l1: 0.120283	valid_1's SMAPE: 12.3027
# [167]	training's l1: 0.12386	training's SMAPE: 12.7235	valid_1's l1: 0.120279	valid_1's SMAPE: 12.3023
# [168]	training's l1: 0.123851	training's SMAPE: 12.7226	valid_1's l1: 0.120279	valid_1's SMAPE: 12.3024
# [169]	training's l1: 0.123845	training's SMAPE: 12.722	valid_1's l1: 0.120262	valid_1's SMAPE: 12.3006
# [170]	training's l1: 0.12384	training's SMAPE: 12.7214	valid_1's l1: 0.120261	valid_1's SMAPE: 12.3006
# [171]	training's l1: 0.123832	training's SMAPE: 12.7206	valid_1's l1: 0.120263	valid_1's SMAPE: 12.3007
# [172]	training's l1: 0.123827	training's SMAPE: 12.7201	valid_1's l1: 0.120259	valid_1's SMAPE: 12.3004
# [173]	training's l1: 0.123819	training's SMAPE: 12.7193	valid_1's l1: 0.120261	valid_1's SMAPE: 12.3005
# [174]	training's l1: 0.123815	training's SMAPE: 12.7189	valid_1's l1: 0.120249	valid_1's SMAPE: 12.2994
# [175]	training's l1: 0.123809	training's SMAPE: 12.7182	valid_1's l1: 0.120248	valid_1's SMAPE: 12.2992
# [176]	training's l1: 0.1238	training's SMAPE: 12.7174	valid_1's l1: 0.120248	valid_1's SMAPE: 12.2993
# [177]	training's l1: 0.123791	training's SMAPE: 12.7165	valid_1's l1: 0.120245	valid_1's SMAPE: 12.299
# [178]	training's l1: 0.123785	training's SMAPE: 12.7158	valid_1's l1: 0.120227	valid_1's SMAPE: 12.2971
# [179]	training's l1: 0.12378	training's SMAPE: 12.7154	valid_1's l1: 0.120227	valid_1's SMAPE: 12.2971
# [180]	training's l1: 0.123772	training's SMAPE: 12.7146	valid_1's l1: 0.120228	valid_1's SMAPE: 12.2972
# [181]	training's l1: 0.123765	training's SMAPE: 12.7138	valid_1's l1: 0.120228	valid_1's SMAPE: 12.2972
# [182]	training's l1: 0.12376	training's SMAPE: 12.7133	valid_1's l1: 0.120216	valid_1's SMAPE: 12.296
# [183]	training's l1: 0.123751	training's SMAPE: 12.7124	valid_1's l1: 0.120216	valid_1's SMAPE: 12.296
# [184]	training's l1: 0.123748	training's SMAPE: 12.712	valid_1's l1: 0.120213	valid_1's SMAPE: 12.2957
# [185]	training's l1: 0.123742	training's SMAPE: 12.7115	valid_1's l1: 0.120214	valid_1's SMAPE: 12.2958
# [186]	training's l1: 0.123735	training's SMAPE: 12.7108	valid_1's l1: 0.120214	valid_1's SMAPE: 12.2958
# [187]	training's l1: 0.123729	training's SMAPE: 12.7102	valid_1's l1: 0.120205	valid_1's SMAPE: 12.2949
# [188]	training's l1: 0.123725	training's SMAPE: 12.7097	valid_1's l1: 0.120205	valid_1's SMAPE: 12.295
# [189]	training's l1: 0.123717	training's SMAPE: 12.709	valid_1's l1: 0.120204	valid_1's SMAPE: 12.2948
# [190]	training's l1: 0.12371	training's SMAPE: 12.7083	valid_1's l1: 0.120202	valid_1's SMAPE: 12.2946
# [191]	training's l1: 0.1237	training's SMAPE: 12.7072	valid_1's l1: 0.120202	valid_1's SMAPE: 12.2947
# [192]	training's l1: 0.123694	training's SMAPE: 12.7066	valid_1's l1: 0.120204	valid_1's SMAPE: 12.2948
# [193]	training's l1: 0.123689	training's SMAPE: 12.7061	valid_1's l1: 0.120204	valid_1's SMAPE: 12.2948
# [194]	training's l1: 0.12368	training's SMAPE: 12.7052	valid_1's l1: 0.120205	valid_1's SMAPE: 12.2949
# [195]	training's l1: 0.123674	training's SMAPE: 12.7045	valid_1's l1: 0.120203	valid_1's SMAPE: 12.2948
# [196]	training's l1: 0.123666	training's SMAPE: 12.7037	valid_1's l1: 0.120204	valid_1's SMAPE: 12.2949
# [197]	training's l1: 0.123657	training's SMAPE: 12.7028	valid_1's l1: 0.120204	valid_1's SMAPE: 12.2948
# [198]	training's l1: 0.12365	training's SMAPE: 12.7021	valid_1's l1: 0.120201	valid_1's SMAPE: 12.2945
# [199]	training's l1: 0.123644	training's SMAPE: 12.7015	valid_1's l1: 0.120198	valid_1's SMAPE: 12.2943
# [200]	training's l1: 0.123638	training's SMAPE: 12.7009	valid_1's l1: 0.120193	valid_1's SMAPE: 12.2938
# [201]	training's l1: 0.123632	training's SMAPE: 12.7003	valid_1's l1: 0.120194	valid_1's SMAPE: 12.2938
# [202]	training's l1: 0.123626	training's SMAPE: 12.6997	valid_1's l1: 0.120195	valid_1's SMAPE: 12.2939
# [203]	training's l1: 0.123619	training's SMAPE: 12.699	valid_1's l1: 0.120195	valid_1's SMAPE: 12.294
# [204]	training's l1: 0.123614	training's SMAPE: 12.6985	valid_1's l1: 0.120188	valid_1's SMAPE: 12.2933
# [205]	training's l1: 0.123605	training's SMAPE: 12.6976	valid_1's l1: 0.120188	valid_1's SMAPE: 12.2933
# [206]	training's l1: 0.123597	training's SMAPE: 12.6967	valid_1's l1: 0.120179	valid_1's SMAPE: 12.2924
# [207]	training's l1: 0.123593	training's SMAPE: 12.6963	valid_1's l1: 0.120179	valid_1's SMAPE: 12.2924
# [208]	training's l1: 0.123585	training's SMAPE: 12.6955	valid_1's l1: 0.120177	valid_1's SMAPE: 12.2921
# [209]	training's l1: 0.12358	training's SMAPE: 12.695	valid_1's l1: 0.120177	valid_1's SMAPE: 12.2921
# [210]	training's l1: 0.123572	training's SMAPE: 12.6942	valid_1's l1: 0.120178	valid_1's SMAPE: 12.2923
# [211]	training's l1: 0.123565	training's SMAPE: 12.6935	valid_1's l1: 0.120179	valid_1's SMAPE: 12.2924
# [212]	training's l1: 0.123559	training's SMAPE: 12.6928	valid_1's l1: 0.120178	valid_1's SMAPE: 12.2923
# [213]	training's l1: 0.123549	training's SMAPE: 12.6919	valid_1's l1: 0.120179	valid_1's SMAPE: 12.2924
# [214]	training's l1: 0.123545	training's SMAPE: 12.6915	valid_1's l1: 0.12018	valid_1's SMAPE: 12.2924
# [215]	training's l1: 0.123537	training's SMAPE: 12.6906	valid_1's l1: 0.120181	valid_1's SMAPE: 12.2926
# [216]	training's l1: 0.123531	training's SMAPE: 12.69	valid_1's l1: 0.120183	valid_1's SMAPE: 12.2927
# [217]	training's l1: 0.123526	training's SMAPE: 12.6895	valid_1's l1: 0.120176	valid_1's SMAPE: 12.292
# [218]	training's l1: 0.123517	training's SMAPE: 12.6886	valid_1's l1: 0.120174	valid_1's SMAPE: 12.2918
# [219]	training's l1: 0.12351	training's SMAPE: 12.6879	valid_1's l1: 0.120171	valid_1's SMAPE: 12.2915
# [220]	training's l1: 0.123501	training's SMAPE: 12.687	valid_1's l1: 0.120173	valid_1's SMAPE: 12.2917
# [221]	training's l1: 0.123495	training's SMAPE: 12.6863	valid_1's l1: 0.120175	valid_1's SMAPE: 12.292
# [222]	training's l1: 0.123488	training's SMAPE: 12.6856	valid_1's l1: 0.120176	valid_1's SMAPE: 12.2921
# [223]	training's l1: 0.123483	training's SMAPE: 12.6851	valid_1's l1: 0.120174	valid_1's SMAPE: 12.2919
# [224]	training's l1: 0.123474	training's SMAPE: 12.6843	valid_1's l1: 0.120176	valid_1's SMAPE: 12.2921
# [225]	training's l1: 0.123466	training's SMAPE: 12.6834	valid_1's l1: 0.120179	valid_1's SMAPE: 12.2924
# [226]	training's l1: 0.123458	training's SMAPE: 12.6826	valid_1's l1: 0.12018	valid_1's SMAPE: 12.2925
# [227]	training's l1: 0.123452	training's SMAPE: 12.682	valid_1's l1: 0.120179	valid_1's SMAPE: 12.2924
# [228]	training's l1: 0.123447	training's SMAPE: 12.6815	valid_1's l1: 0.120176	valid_1's SMAPE: 12.2921
# [229]	training's l1: 0.123443	training's SMAPE: 12.681	valid_1's l1: 0.12017	valid_1's SMAPE: 12.2914
# [230]	training's l1: 0.123435	training's SMAPE: 12.6803	valid_1's l1: 0.120171	valid_1's SMAPE: 12.2916
# [231]	training's l1: 0.123427	training's SMAPE: 12.6795	valid_1's l1: 0.120174	valid_1's SMAPE: 12.2919
# [232]	training's l1: 0.123421	training's SMAPE: 12.6789	valid_1's l1: 0.120174	valid_1's SMAPE: 12.2919
# [233]	training's l1: 0.123413	training's SMAPE: 12.6781	valid_1's l1: 0.120176	valid_1's SMAPE: 12.292
# [234]	training's l1: 0.123407	training's SMAPE: 12.6775	valid_1's l1: 0.120178	valid_1's SMAPE: 12.2922
# [235]	training's l1: 0.123403	training's SMAPE: 12.677	valid_1's l1: 0.120177	valid_1's SMAPE: 12.2921
# [236]	training's l1: 0.123397	training's SMAPE: 12.6764	valid_1's l1: 0.120176	valid_1's SMAPE: 12.2921
# [237]	training's l1: 0.123391	training's SMAPE: 12.6758	valid_1's l1: 0.120177	valid_1's SMAPE: 12.2922
# [238]	training's l1: 0.123384	training's SMAPE: 12.675	valid_1's l1: 0.120177	valid_1's SMAPE: 12.2922
# [239]	training's l1: 0.123378	training's SMAPE: 12.6745	valid_1's l1: 0.120177	valid_1's SMAPE: 12.2922
# [240]	training's l1: 0.123373	training's SMAPE: 12.6739	valid_1's l1: 0.120174	valid_1's SMAPE: 12.2919
# [241]	training's l1: 0.123367	training's SMAPE: 12.6734	valid_1's l1: 0.120172	valid_1's SMAPE: 12.2917
# [242]	training's l1: 0.123361	training's SMAPE: 12.6728	valid_1's l1: 0.120174	valid_1's SMAPE: 12.2919
# [243]	training's l1: 0.123353	training's SMAPE: 12.672	valid_1's l1: 0.120177	valid_1's SMAPE: 12.2922
# [244]	training's l1: 0.123348	training's SMAPE: 12.6714	valid_1's l1: 0.120179	valid_1's SMAPE: 12.2924
# [245]	training's l1: 0.123342	training's SMAPE: 12.6708	valid_1's l1: 0.120181	valid_1's SMAPE: 12.2926
# [246]	training's l1: 0.123334	training's SMAPE: 12.67	valid_1's l1: 0.120183	valid_1's SMAPE: 12.2928
# [247]	training's l1: 0.123331	training's SMAPE: 12.6698	valid_1's l1: 0.120182	valid_1's SMAPE: 12.2928
# [248]	training's l1: 0.123326	training's SMAPE: 12.6692	valid_1's l1: 0.120185	valid_1's SMAPE: 12.293
# [249]	training's l1: 0.12332	training's SMAPE: 12.6686	valid_1's l1: 0.120185	valid_1's SMAPE: 12.293
# Early stopping, best iteration is:
# [229]	training's l1: 0.123443	training's SMAPE: 12.681	valid_1's l1: 0.12017	valid_1's SMAPE: 12.2914
# ---------- ******************** ----------
# Root mean_squared_error -------------------- 0.15508278527324587

# %% [markdown]
# ### 6.0 Model evaluation

# %%
#print('Root mean_squared_error',np.sqrt(mean_squared_error(y_test, y_pred)))

# %%
# Feature importance
lgb.plot_importance(model,max_num_features=20);

# %%
sns.distplot(y_pred_new)
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
y_pred_new1 = np.exp(y_pred_new)-1
submit = pd.DataFrame({'id': test['id'], 'sales':(y_pred_new1)})
submit.to_csv('store_submit.csv',index=False)
submit.head()
# Out:
#    id      sales
# 0   0  11.355863
# 1   1  12.966846
# 2   2  13.343881
# 3   3  13.982647
# 4   4  14.944373

# %% [markdown]
# ## Thank you
